# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

import windIO
import foam
import wind

# %%
maindir = "D:/tempData_depot/simData_CandC/schemes/"
# caseNames = ["tngE2.c1", "tngE2.t.bw", "tngE2.t.cn", "tngE2.t.cn.9", "vwt.base", "vwt.t.bw", "vwt.t.cn", "vwt.t.cn.9"]
caseNames = ["vwt.base", "vwt.t.bw", "vwt.t.cn", "vwt.t.cn.9", "vwt.t.cn.pmpl"]
# caseNames = ["tngE2.c1", "tngE2.t.bw", "tngE2.t.cn", "tngE2.t.cn.9"]

probeName = 'smpl.zProf_x0y0'
H = 0.08

# %%
les = []
for cn in caseNames:
    caseDir = os.path.join(maindir,cn)
    print(caseDir)
    df = foam.processVelProfile(caseDir,probeName=probeName,name=cn,exportPlots=False, trimTimeSegs=[[0,1.0]],H=H)
    les.append(df)
# Out:
# D:/tempData_depot/simData_CandC/schemes/vwt.base
# Processing OpenFOAM case:	D:/tempData_depot/simData_CandC/schemes/vwt.base
# Probe read from:		D:/tempData_depot/simData_CandC/schemes/vwt.base/postProcessing/smpl.zProf_x0y0
# Target profile read from:	None
#   >> Reading probe data ...
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.base/postProcessing/smpl.zProf_x0y0/0/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.base/postProcessing/smpl.zProf_x0y0/7.2/U
#     Trimming overlapping times.
#    Trimming times: [[0, 1.0]]
#     Adopted time step: 0.002
#              << Done!
#   >> Processing profile data.
#              << Done!
#   >> Finished reading probe data.
# D:/tempData_depot/simData_CandC/schemes/vwt.t.bw
# Processing OpenFOAM case:	D:/tempData_depot/simData_CandC/schemes/vwt.t.bw
# Probe read from:		D:/tempData_depot/simData_CandC/schemes/vwt.t.bw/postProcessing/smpl.zProf_x0y0
# Target profile read from:	None
#   >> Reading probe data ...
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.bw/postProcessing/smpl.zProf_x0y0/0/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.bw/postProcessing/smpl.zProf_x0y0/7.7/U
#     Trimming overlapping times.
#    Trimming times: [[0, 1.0]]
#     Adopted time step: 0.002
#              << Done!
#   >> Processing profile data.
#              << Done!
#   >> Finished reading probe data.
# D:/tempData_depot/simData_CandC/schemes/vwt.t.cn
# Processing OpenFOAM case:	D:/tempData_depot/simData_CandC/schemes/vwt.t.cn
# Probe read from:		D:/tempData_depot/simData_CandC/schemes/vwt.t.cn/postProcessing/smpl.zProf_x0y0
# Target profile read from:	None
#   >> Reading probe data ...
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn/postProcessing/smpl.zProf_x0y0/0/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn/postProcessing/smpl.zProf_x0y0/8.1/U
#     Trimming overlapping times.
#    Trimming times: [[0, 1.0]]
#     Adopted time step: 0.002
#              << Done!
#   >> Processing profile data.
#              << Done!
#   >> Finished reading probe data.
# D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.9
# Processing OpenFOAM case:	D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.9
# Probe read from:		D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.9/postProcessing/smpl.zProf_x0y0
# Target profile read from:	None
#   >> Reading probe data ...
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.9/postProcessing/smpl.zProf_x0y0/0/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.9/postProcessing/smpl.zProf_x0y0/0.7/U
#     Trimming overlapping times.
#    Trimming times: [[0, 1.0]]
#     Adopted time step: 0.002
#              << Done!
#   >> Processing profile data.
#              << Done!
#   >> Finished reading probe data.
# D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl
# Processing OpenFOAM case:	D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl
# Probe read from:		D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0
# Target profile read from:	None
#   >> Reading probe data ...
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/0/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/0.28/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/1.76/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/2.76/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/4.14/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/6.44/U
#            reading U from: D:/tempData_depot/simData_CandC/schemes/vwt.t.cn.pmpl/postProcessing/smpl.zProf_x0y0/6.88/U
#     Trimming overlapping times.
#    Trimming times: [[0, 1.0]]
#     Adopted time step: 0.002
#              << Done!
#   >> Processing profile data.
#              << Done!
#   >> Finished reading probe data.

# %%
vel = wind.Profiles(les)
vel.plotProfiles()

yl = [1e-10,3e-0]
vel.plotSpectra(yLimits=[yl,yl,yl],normalize=False)

yl = [1e-9,3e-2]
vel.plotSpectra(yLimits=[yl,yl,yl],normalize=True)

# %%
# vel.plotTimeHistory(figSize=[15,10], xLimits=[0,1])

plt.figure(figsize=[15,10])
# plt.subplots(3,1,sharey=True)
tlim = [1,1.1]
ax1 = plt.subplot(3,1,1)
ax2 = plt.subplot(3,1,2)
ax3 = plt.subplot(3,1,3)

for v in vel:
    ax1.plot(v.t ,v.SpectH.UofT, label=v.name)
    ax1.set_xlim(tlim)
    ax1.legend()

    ax2.plot(v.t ,v.SpectH.VofT, label=v.name)
    ax2.set_xlim(tlim)
    
    ax3.plot(v.t ,v.SpectH.WofT, label=v.name)
    ax3.set_xlim(tlim)

# %%
xtime = {
    'vwt.base': 42190.23+35915.66,
    'vwt.t.bw': 0,
    'vwt.t.cn': 40711.3+38816.36,
    'vwt.t.cn.9': 9157.64+3486.99+42205.72+11065.7
    }

# %%
dir = 'D:/OneDrive - The University of Western Ontario/Documents/Misc/Collegues/Kate/ThesisWork/Data/'
z0 = 0.012
Iu = 0.159
h = 10.3

es = wind.ESDU85(z0=z0, Zref=h)
ess = es.toProfileObj()
print(ess.IuH)
ess.plotProfiles()

prof = pd.DataFrame()
prof['Z'] = ess.Z
prof['U'] = ess.U
prof['Iu'] = ess.Iu
prof['Iv'] = ess.Iv
prof['Iw'] = ess.Iw
prof['xLu'] = ess.xLu
prof['xLv'] = ess.xLv
prof['xLw'] = ess.xLw
prof.to_csv(dir+'ESDU85_prof_z0_'+str(z0)+'.csv',index=False)


es2 = wind.ESDU74(z0=z0, Zref=h)
ess2 = es2.toProfileObj()
ess2.SpectH.plotSpectra()

spect = pd.DataFrame()
spect['n'] = ess2.SpectH.n
spect['Suu'] = ess2.SpectH.Suu
spect['Svv'] = ess2.SpectH.Svv
spect['Sww'] = ess2.SpectH.Sww
spect['nH/U'] = ess2.SpectH.rf()
spect['nSuu/Uh^2'] = ess2.SpectH.rSuu()
spect['nSvv/Uh^2'] = ess2.SpectH.rSvv()
spect['nSww/Uh^2'] = ess2.SpectH.rSww()
spect.to_csv(dir+'ESDU74_spect_z0_'+str(z0)+'.csv',index=False)
# Out:
# 0.15967164817842866
